# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from collections import defaultdict, OrderedDict
from pathlib import Path

from read_output_file import OutputFileParser, ParserToDataFrame
import plot_boss_statistics as pp

# %% [markdown]
# ## Plot sample locations and task choice

# %% [markdown]
# ### Using low fidelity

# %%
experiments = [
    f'uhf_lf_2d_elcb_strategy{idx}_run0' for idx in [1,3,6,10]]
for experiment in experiments:
    pp.plot_multitask_sample_locations_with_bincounts(
        experiment, 'data/out_dualtask', samples_over_iteration=True)

# %%
pp.plot_multitask_sample_locations_with_bincounts(
    'uhf_lf_2d_mumbo_inseparable_run0', 'data/out_dualtask',
    samples_over_iteration=True)

# %% [markdown]
# ### Using high fidelity

# %%
experiments = [
    f'uhf_hf_2d_elcb_strategy{idx}_run0' for idx in [1,3,6,10]]
for experiment in experiments:
    pp.plot_multitask_sample_locations_with_bincounts(
        experiment, 'data/out_dualtask', samples_over_iteration=True)

# %%
pp.plot_multitask_sample_locations_with_bincounts(
    'uhf_hf_2d_mumbo_inseparable_run0', 'data/out_dualtask',
    samples_over_iteration=True)
